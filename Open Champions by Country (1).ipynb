# %%
# Webscraped wikipedia page to get Open Championship Winners, then presented % by country in pie chart

# %%
#Instal necessary packages
# !pip install lxml
# !pip install BeautifulSoup4
from bs4 import BeautifulSoup #sometimes issues installing BeautifulSoup so included two ways 
import numpy as np
import pandas as pd 
import requests 
from urllib.request import urlopen
import ssl
import csv
# Out:
# Requirement already satisfied: lxml in c:\users\amax3\anaconda3\lib\site-packages (4.6.3)
# Requirement already satisfied: BeautifulSoup4 in c:\users\amax3\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\amax3\anaconda3\lib\site-packages (from BeautifulSoup4) (2.2.1)

# %%
#get data from Wikipedia page
source = requests.get('https://en.wikipedia.org/wiki/List_of_The_Open_Championship_champions').text #change to your wikipedia link containing list

soup = BeautifulSoup(source, 'lxml')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of The Open Championship champions - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"89539cfb-8fa7-4750-b75b-047ea5b9f2ea","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_The_Open_Championship_champions","wgTitle":"List of The Open Championship champions","wgCurRevisionId":1055436650,"wgRevisionId":1055436650,"wgArticleId":18541861,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with dead external links","Articles with dead external links from September 2017","Articles with permanently dead external links","Articles with short description","Short description matches Wikidata","Articles with hCards",
# "Pages using div col with small parameter","Featured lists","The Open Championship","Lists of male golfers","Winners of men's major golf championships"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_The_Open_Championship_champions","wgRelevantArticleId":18541861,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"skin":"vector","wgFlaggedRevsParams":{"tags":{"status":{"levels":-1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":60000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":
# "interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q6599896","wgGENewcomerTasksGuidanceEnabled":true,"wgGEAskQuestionEnabled":false,"wgGELinkRecommendationsFrontendEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","mmv.head","mmv.bootstrap.autostart",
# "ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1i9g4",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.38.0-wmf.19" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/HarryVardon.jpg/1200px-HarryVardon.jpg" property="og:image"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="1612" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/HarryVardon.jpg/800px-HarryVardon.jpg" property="og:image"/>
#   <meta content="800" property="og:image:width"/>
#   <meta content="1075" property="og:image:height"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/3/33/HarryVardon.jpg/640px-HarryVardon.jpg" property="og:image"/>
#   <meta content="640" property="og:image:width"/>
#   <meta content="860" property="og:image:height"/>
#   <meta content="List of The Open Championship champions - Wikipedia" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//en.m.wikipedia.org/wiki/List_of_The_Open_Championship_champions" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=List_of_The_Open_Championship_champions&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://en.wikipedia.org/wiki/List_of_The_Open_Championship_champions" rel="canonical"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-List_of_The_Open_Championship_champions rootpage-List_of_The_Open_Championship_champions skin-vector action-view skin-vector-legacy">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators">
#     <div class="mw-indicator" id="mw-indicator-featured-star">
#      <a href="/wiki/Wikipedia:Featured_lists" title="This is a featured list. Click here for more information.">
#       <img alt="This is a featured list. Click here for more information." data-file-height="438" data-file-width="462" decoding="async" height="19" src="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/30px-Cscr-featured.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/40px-Cscr-featured.svg.png 2x" width="20"/>
#      </a>
#     </div>
#    </div>
#    <h1 class="firstHeading mw-first-heading" id="firstHeading">
#     List of The Open Championship champions
#    </h1>
#    <div class="vector-body" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="contentSub2">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#searchInput">
#      Jump to search
#     </a>
#     <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">
#        Wikimedia list article
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:202px;">
#         <a class="image" href="/wiki/File:HarryVardon.jpg">
#          <img alt="" class="thumbimage" data-file-height="3179" data-file-width="2366" decoding="async" height="269" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/33/HarryVardon.jpg/200px-HarryVardon.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/33/HarryVardon.jpg/300px-HarryVardon.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/33/HarryVardon.jpg/400px-HarryVardon.jpg 2x" width="200"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:HarryVardon.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Harry_Vardon" title="Harry Vardon">
#           Harry Vardon
#          </a>
#          , six-time Open Champion in 1896, 1898, 1899, 1903, 1911, and 1914, which is a record
#         </div>
#        </div>
#       </div>
#       <p>
#        <a href="/wiki/The_Open_Championship" title="The Open Championship">
#         The Open Championship
#        </a>
#        is an annual
#        <a href="/wiki/Golf" title="Golf">
#         golf
#        </a>
#        competition held in the
#        <a href="/wiki/United_Kingdom" title="United Kingdom">
#         United Kingdom
#        </a>
#        that was established in 1860.
#        <sup class="reference" id="cite_ref-1">
#         <a href="#cite_note-1">
#          [1]
#         </a>
#        </sup>
#        It is played on the weekend of the third Friday in July, and is the last of the four
#        <a href="/wiki/Men%27s_major_golf_championships" title="Men's major golf championships">
#         major championships
#        </a>
#        to be played each year.
#        <sup class="reference" id="cite_ref-2">
#         <a href="#cite_note-2">
#          [2]
#         </a>
#        </sup>
#        In addition, this championship is conducted by
#        <a href="/wiki/The_Royal_and_Ancient_Golf_Club_of_St_Andrews" title="The Royal and Ancient Golf Club of St Andrews">
#         The Royal and Ancient Golf Club of St Andrews
#        </a>
#        (R&amp;A). The championship was not held in 1871 due to a disagreement over a new trophy,
#        <sup class="reference" id="cite_ref-NotHeld_3-0">
#         <a href="#cite_note-NotHeld-3">
#          [3]
#         </a>
#        </sup>
#        and from 1915 to 1919 and from 1940 to 1945 due to the
#        <a href="/wiki/World_War_I" title="World War I">
#         First
#        </a>
#        and
#        <a href="/wiki/World_War_II" title="World War II">
#         Second
#        </a>
#        World Wars respectively.
#       </p>
#       <p>
#        The reigning champion of the competition is automatically invited to play in the other three majors (
#        <a href="/wiki/Masters_Tournament" title="Masters Tournament">
#         Masters
#        </a>
#        , the
#        <a href="/wiki/U.S._Open_(golf)" title="U.S. Open (golf)">
#         U.S. Open
#        </a>
#        , and the
#        <a href="/wiki/PGA_Championship" title="PGA Championship">
#         PGA Championship
#        </a>
#        ) for the next five years. The prize of the tournament is the Golf Champion Trophy, commonly known as the
#        <a href="/wiki/Claret_Jug" title="Claret Jug">
#         Claret Jug
#        </a>
#        , and the champion personally keeps the trophy until the next competition the following year. The champion also receives a gold medal, which they are allowed to keep permanently. Until 1870 the champion received the
#        <a href="/wiki/Challenge_Belt" title="Challenge Belt">
#         Challenge Belt
#        </a>
#        , however when Tom Morris Jr. (more commonly known as
#        <a href="/wiki/Young_Tom_Morris" title="Young Tom Morris">
#         Young Tom Morris
#        </a>
#        ) won the Open Championship three times in a row he won the belt outright, necessitating the need for a new trophy.
#        <sup class="reference" id="cite_ref-NotHeld_3-1">
#         <a href="#cite_note-NotHeld-3">
#          [3]
#         </a>
#        </sup>
#       </p>
#       <p>
#        <a href="/wiki/Harry_Vardon" title="Harry Vardon">
#         Harry Vardon
#        </a>
#        holds the record for the most Open Championship victories, winning six times during his career. The oldest winner of the Open Championship is Tom Morris Sr. (or
#        <a href="/wiki/Old_Tom_Morris" title="Old Tom Morris">
#         Old Tom Morris
#        </a>
#        ) who was 46 years and 102 days old when he won in
#        <a href="/wiki/1867_Open_Championship" title="1867 Open Championship">
#         1867
#        </a>
#        . His son, Tom Morris Jr., is the youngest winner of the championship, he was 17 years and 156 days old when he won the
#        <a href="/wiki/1868_Open_Championship" title="1868 Open Championship">
#         1868 Open Championship
#        </a>
#        . He also won the most consecutive times with four victories (1868–1872).
#        <a href="/wiki/Henrik_Stenson" title="Henrik Stenson">
#         Henrik Stenson
#        </a>
#        holds the dual distinction of being both the most strokes under
#        <a href="/wiki/Par_(score)" title="Par (score)">
#         par
#        </a>
#        for 72 holes (−20) and also recording the lowest total score (264) when he won in
#        <a href="/wiki/2016_Open_Championship" title="2016 Open Championship">
#         2016
#        </a>
#        .
#       </p>
#       <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation">
#        <input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/>
#        <div class="toctitle" dir="ltr" lang="en">
#         <h2 id="mw-toc-heading">
#          Contents
#         </h2>
#         <span class="toctogglespan">
#          <label class="toctogglelabel" for="toctogglecheckbox">
#          </label>
#         </span>
#        </div>
#        <ul>
#         <li class="toclevel-1 tocsection-1">
#          <a href="#Champions">
#           <span class="tocnumber">
#            1
#           </span>
#           <span class="toctext">
#            Champions
#           </span>
#          </a>
#          <ul>
#           <li class="toclevel-2 tocsection-2">
#            <a href="#By_year">
#             <span class="tocnumber">
#              1.1
#             </span>
#             <span class="toctext">
#              By year
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-3">
#            <a href="#Multiple_champions">
#             <span class="tocnumber">
#              1.2
#             </span>
#             <span class="toctext">
#              Multiple champions
#             </span>
#            </a>
#           </li>
#           <li class="toclevel-2 tocsection-4">
#            <a href="#By_nationality">
#             <span class="tocnumber">
#              1.3
#             </span>
#             <span class="toctext">
#              By nationality
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="toclevel-1 tocsection-5">
#          <a href="#Notes">
#           <span class="tocnumber">
#            2
#           </span>
#           <span class="toctext">
#            Notes
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-6">
#          <a href="#References">
#           <span class="tocnumber">
#            3
#           </span>
#           <span class="toctext">
#            References
#           </span>
#          </a>
#         </li>
#         <li class="toclevel-1 tocsection-7">
#          <a href="#External_links">
#           <span class="tocnumber">
#            4
#           </span>
#           <span class="toctext">
#            External links
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <h2>
#        <span class="mw-headline" id="Champions">
#         Champions
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_The_Open_Championship_champions&amp;action=edit&amp;section=1" title="Edit section: Champions">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h2>
#       <table class="wikitable">
#        <caption>
#         Key
#        </caption>
#        <tbody>
#         <tr>
#          <td>
#           <i>
#            (n/a)
#           </i>
#          </td>
#          <td>
#           Information not available
#          </td>
#         </tr>
#         <tr>
#          <td align="center" style="background-color:#cedff2" width="40px">
#           <img alt="Tournament won in a playoff" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
#          </td>
#          <td>
#           Tournament won in a
#           <a href="/wiki/Playoff_(golf)" title="Playoff (golf)">
#            playoff
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" style="background-color:#FBCEB1" width="40px">
#           *
#          </td>
#          <td>
#           Tournament won by an
#           <a href="/wiki/Amateur" title="Amateur">
#            amateur
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <h3>
#        <span class="mw-headline" id="By_year">
#         By year
#        </span>
#        <span class="mw-editsection">
#         <span class="mw-editsection-bracket">
#          [
#         </span>
#         <a href="/w/index.php?title=List_of_The_Open_Championship_champions&amp;action=edit&amp;section=2" title="Edit section: By year">
#          edit
#         </a>
#         <span class="mw-editsection-bracket">
#          ]
#         </span>
#        </span>
#       </h3>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:James_Braid_(golfer)_1913.jpg">
#          <img alt="" class="thumbimage" data-file-height="551" data-file-width="327" decoding="async" height="286" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c0/James_Braid_%28golfer%29_1913.jpg/170px-James_Braid_%28golfer%29_1913.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c0/James_Braid_%28golfer%29_1913.jpg/255px-James_Braid_%28golfer%29_1913.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/c/c0/James_Braid_%28golfer%29_1913.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:James_Braid_(golfer)_1913.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/James_Braid_(golfer)" title="James Braid (golfer)">
#           James Braid
#          </a>
#          , five-time Open Champion in 1901, 1905, 1906, 1908, and 1910
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:JohnHenryTaylor.jpg">
#          <img alt="" class="thumbimage" data-file-height="1536" data-file-width="1004" decoding="async" height="260" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/11/JohnHenryTaylor.jpg/170px-JohnHenryTaylor.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/11/JohnHenryTaylor.jpg/255px-JohnHenryTaylor.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/11/JohnHenryTaylor.jpg/340px-JohnHenryTaylor.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:JohnHenryTaylor.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/John_Henry_Taylor" title="John Henry Taylor">
#           John Henry Taylor
#          </a>
#          , five-time Open Champion in 1894, 1895, 1900, 1909, 1913
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:2008_Open_Championship_-_Tom_Watson.jpg">
#          <img alt="" class="thumbimage" data-file-height="1024" data-file-width="685" decoding="async" height="254" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/99/2008_Open_Championship_-_Tom_Watson.jpg/170px-2008_Open_Championship_-_Tom_Watson.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/99/2008_Open_Championship_-_Tom_Watson.jpg/255px-2008_Open_Championship_-_Tom_Watson.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/99/2008_Open_Championship_-_Tom_Watson.jpg/340px-2008_Open_Championship_-_Tom_Watson.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:2008_Open_Championship_-_Tom_Watson.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Tom_Watson_(golfer)" title="Tom Watson (golfer)">
#           Tom Watson
#          </a>
#          , five-time Open Champion in 1975, 1977, 1980, 1982, 1983
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:Old_and_Young_Tom_Morris.jpg">
#          <img alt="" class="thumbimage" data-file-height="527" data-file-width="371" decoding="async" height="241" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Old_and_Young_Tom_Morris.jpg/170px-Old_and_Young_Tom_Morris.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Old_and_Young_Tom_Morris.jpg/255px-Old_and_Young_Tom_Morris.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Old_and_Young_Tom_Morris.jpg/340px-Old_and_Young_Tom_Morris.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Old_and_Young_Tom_Morris.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Old_Tom_Morris" title="Old Tom Morris">
#           Tom Morris Sr.
#          </a>
#          , four-time Open Champion in 1861, 1862, 1864, and 1867.
#          <br/>
#          <a href="/wiki/Young_Tom_Morris" title="Young Tom Morris">
#           Tom Morris Jr.
#          </a>
#          , four-time Open Champion in 1868, 1869, 1870, and 1872.
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:Willie_Park_Senior_wearing_the_Championship_Belt.jpg">
#          <img alt="" class="thumbimage" data-file-height="1024" data-file-width="713" decoding="async" height="244" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Willie_Park_Senior_wearing_the_Championship_Belt.jpg/170px-Willie_Park_Senior_wearing_the_Championship_Belt.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Willie_Park_Senior_wearing_the_Championship_Belt.jpg/255px-Willie_Park_Senior_wearing_the_Championship_Belt.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Willie_Park_Senior_wearing_the_Championship_Belt.jpg/340px-Willie_Park_Senior_wearing_the_Championship_Belt.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Willie_Park_Senior_wearing_the_Championship_Belt.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Willie_Park_Sr." title="Willie Park Sr.">
#           Willie Park Sr.
#          </a>
#          , four-time Open Champion in 1860, 1863, 1866, and 1875
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:Walter_Hagen_1914.png">
#          <img alt="" class="thumbimage" data-file-height="664" data-file-width="469" decoding="async" height="241" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Walter_Hagen_1914.png/170px-Walter_Hagen_1914.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Walter_Hagen_1914.png/255px-Walter_Hagen_1914.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/d/d5/Walter_Hagen_1914.png/340px-Walter_Hagen_1914.png 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Walter_Hagen_1914.png" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Walter_Hagen" title="Walter Hagen">
#           Walter Hagen
#          </a>
#          , four-time Open Champion in 1922, 1924, 1928, and 1929
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:1880-82_Open_Champion_Bob_Ferguson.jpg">
#          <img alt="" class="thumbimage" data-file-height="280" data-file-width="189" decoding="async" height="252" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/54/1880-82_Open_Champion_Bob_Ferguson.jpg/170px-1880-82_Open_Champion_Bob_Ferguson.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/5/54/1880-82_Open_Champion_Bob_Ferguson.jpg 1.5x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:1880-82_Open_Champion_Bob_Ferguson.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Bob_Ferguson_(golfer)" title="Bob Ferguson (golfer)">
#           Bob Ferguson
#          </a>
#          , three-time Open Champion in 1880, 1881, 1882
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:BobbyJonesAge14.jpg">
#          <img alt="" class="thumbimage" data-file-height="777" data-file-width="336" decoding="async" height="393" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/75/BobbyJonesAge14.jpg/170px-BobbyJonesAge14.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/75/BobbyJonesAge14.jpg/255px-BobbyJonesAge14.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/7/75/BobbyJonesAge14.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:BobbyJonesAge14.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Bobby_Jones_(golfer)" title="Bobby Jones (golfer)">
#           Bobby Jones
#          </a>
#          , three-time Open Champion in 1926, 1927, and 1930.  He is one of six champions to win wire-to-wire after 72-holes played with his victory in 1927.
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:Henry-Cotton_1931.jpg">
#          <img alt="" class="thumbimage" data-file-height="994" data-file-width="694" decoding="async" height="243" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Henry-Cotton_1931.jpg/170px-Henry-Cotton_1931.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Henry-Cotton_1931.jpg/255px-Henry-Cotton_1931.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7c/Henry-Cotton_1931.jpg/340px-Henry-Cotton_1931.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Henry-Cotton_1931.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Henry_Cotton_(golfer)" title="Henry Cotton (golfer)">
#           Henry Cotton
#          </a>
#          , three-time Open Champion in 1934, 1937, and 1948.  He is one of six champions to win wire-to-wire after 72-holes played with his victory in 1934.
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:All_Black.jpg">
#          <img alt="" class="thumbimage" data-file-height="1475" data-file-width="1500" decoding="async" height="167" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/All_Black.jpg/170px-All_Black.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e5/All_Black.jpg/255px-All_Black.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e5/All_Black.jpg/340px-All_Black.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:All_Black.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Gary_Player" title="Gary Player">
#           Gary Player
#          </a>
#          , three-time Open Champion in 1959, 1968, and 1974.
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:JackNicklaus.cropped.jpg">
#          <img alt="" class="thumbimage" data-file-height="672" data-file-width="712" decoding="async" height="160" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7f/JackNicklaus.cropped.jpg/170px-JackNicklaus.cropped.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7f/JackNicklaus.cropped.jpg/255px-JackNicklaus.cropped.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/7f/JackNicklaus.cropped.jpg/340px-JackNicklaus.cropped.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:JackNicklaus.cropped.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Jack_Nicklaus" title="Jack Nicklaus">
#           Jack Nicklaus
#          </a>
#          , three-time Open Champion in 1966, 1970, and 1978
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:Seve_Ballesteros_2006-07-19.jpg">
#          <img alt="" class="thumbimage" data-file-height="1779" data-file-width="2226" decoding="async" height="136" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/60/Seve_Ballesteros_2006-07-19.jpg/170px-Seve_Ballesteros_2006-07-19.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/60/Seve_Ballesteros_2006-07-19.jpg/255px-Seve_Ballesteros_2006-07-19.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/60/Seve_Ballesteros_2006-07-19.jpg/340px-Seve_Ballesteros_2006-07-19.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Seve_Ballesteros_2006-07-19.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Seve_Ballesteros" title="Seve Ballesteros">
#           Seve Ballesteros
#          </a>
#          , three-time Open Champion in 1979, 1984, and 1988
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:Nick_Faldo.jpg">
#          <img alt="" class="thumbimage" data-file-height="505" data-file-width="367" decoding="async" height="234" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Nick_Faldo.jpg/170px-Nick_Faldo.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Nick_Faldo.jpg/255px-Nick_Faldo.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Nick_Faldo.jpg/340px-Nick_Faldo.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Nick_Faldo.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Nick_Faldo" title="Nick Faldo">
#           Nick Faldo
#          </a>
#          , three-time Open Champion in 1987, 1990, and 1992
#         </div>
#        </div>
#       </div>
#       <div class="thumb tright">
#        <div class="thumbinner" style="width:172px;">
#         <a class="image" href="/wiki/File:Tiger_Woods_drives_by_Allison.jpg">
#          <img alt="" class="thumbimage" data-file-height="2592" data-file-width="3426" decoding="async" height="129" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Tiger_Woods_drives_by_Allison.jpg/170px-Tiger_Woods_drives_by_Allison.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Tiger_Woods_drives_by_Allison.jpg/255px-Tiger_Woods_drives_by_Allison.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Tiger_Woods_drives_by_Allison.jpg/340px-Tiger_Woods_drives_by_Allison.jpg 2x" width="170"/>
#         </a>
#         <div class="thumbcaption">
#          <div class="magnify">
#           <a class="internal" href="/wiki/File:Tiger_Woods_drives_by_Allison.jpg" title="Enlarge">
#           </a>
#          </div>
#          <a href="/wiki/Tiger_Woods" title="Tiger Woods">
#           Tiger Woods
#          </a>
#          , three-time Open Champion in 2000, 2005, and 2006.  He is one of six champions to win wire-to-wire after 72-holes played with his victory in 2005.
#         </div>
#        </div>
#       </div>
#       <table class="sortable plainrowheaders wikitable" style="text-align:left;">
#        <caption>
#         The Open Championship champions
#        </caption>
#        <tbody>
#         <tr>
#          <th scope="col">
#           Year
#          </th>
#          <th scope="col">
#           Country
#          </th>
#          <th scope="col">
#           Champion
#          </th>
#          <th scope="col">
#           Course
#          </th>
#          <th scope="col">
#           Location
#          </th>
#          <th scope="col">
#           Total score
#          </th>
#          <th scope="col">
#           To
#           <a href="/wiki/Par_(score)" title="Par (score)">
#            par
#           </a>
#           <sup class="reference" id="ref_Note2b">
#            <a href="#endnote_Note2b">
#             [b]
#            </a>
#           </sup>
#          </th>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1860_Open_Championship" title="1860 Open Championship">
#            1860
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Park, Willie Sr.">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Willie_Park_Sr." title="Willie Park Sr.">
#               Willie Park Sr.
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
#          <td align="center">
#           174
#          </td>
#          <td align="center">
#           <i>
#            n/a
#           </i>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1861_Open_Championship" title="1861 Open Championship">
#            1861
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Morris Sr., Tom">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Old_Tom_Morris" title="Old Tom Morris">
#               Tom Morris Sr.
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
#          <td align="center">
#           163
#          </td>
#          <td align="center">
#           <i>
#            n/a
#           </i>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1862_Open_Championship" title="1862 Open Championship">
#            1862
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Morris Sr., Tom">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Old_Tom_Morris" title="Old Tom Morris">
#               Tom Morris Sr.
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
#          <td align="center">
#           163
#          </td>
#          <td align="center">
#           <i>
#            n/a
#           </i>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1863_Open_Championship" title="1863 Open Championship">
#            1863
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Park, Willie Sr.">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Willie_Park_Sr." title="Willie Park Sr.">
#               Willie Park Sr.
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
#          <td align="center">
#           168
#          </td>
#          <td align="center">
#           <i>
#            n/a
#           </i>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1864_Open_Championship" title="1864 Open Championship">
#            1864
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Morris Sr., Tom">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Old_Tom_Morris" title="Old Tom Morris">
#               Tom Morris Sr.
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
#          <td align="center">
#           167
#          </td>
#          <td align="center">
#           <i>
#            n/a
#           </i>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1865_Open_Championship" title="1865 Open Championship">
#            1865
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Strath, Andrew">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Andrew_Strath" title="Andrew Strath">
#               Andrew Strath
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
#          <td align="center">
#           162
#          </td>
#          <td align="center">
#           <i>
#            n/a
#           </i>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1866_Open_Championship" title="1866 Open Championship">
#            1866
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Park, Willie Sr.">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Willie_Park_Sr." title="Willie Park Sr.">
#               Willie Park Sr.
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
#          <td align="center">
#           169
#          </td>
#          <td align="center">
#           <i>
#            n/a
#           </i>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="text-align:center">
#           <a href="/wiki/1867_Open_Championship" title="1867 Open Championship">
#            1867
#           </a>
#          </th>
#          <td>
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/23px-Flag_of_Scotland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/35px-Flag_of_Scotland.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/10/Flag_of_Scotland.svg/46px-Flag_of_Scotland.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Scotland" title="Scotland">
#            Scotland
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Morris Sr., Tom">
#            <span class="vcard">
#             <span class="fn">
#              <a href="/wiki/Old_Tom_Morris" title="Old Tom Morris">
#               Tom Morris Sr.
#              </a>
#             </span>
#            </span>
#           </span>
#          </td>
#          <td>
#           <a href="/wiki/Prestwick_Golf_Club" title="Prestwick Golf Club">
#            Prestwick Golf Club
#           </a>
#          </td>
#          <td>
#           <span data-sort-value="Scotland, Prestwick !">
#            <a href="/wiki/Prestwick" title="Prestwick">
#             Prestwick
#            </a>
#            ,
#            <a href="/wiki/Scotland" title="Scotland">
#             Scotland
#            </a>
#           </span>
#          </td>
# ...
#           <span>
#            View history
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <nav aria-labelledby="p-cactions-label" class="mw-portlet mw-portlet-cactions emptyPortlet vector-menu-dropdown-noicon vector-menu vector-menu-dropdown" id="p-cactions" role="navigation" title="More options">
#       <input aria-haspopup="true" aria-labelledby="p-cactions-label" class="vector-menu-checkbox" data-event-name="ui.dropdown-p-cactions" id="p-cactions-checkbox" role="button" type="checkbox"/>
#       <h3 aria-label="" class="vector-menu-heading" id="p-cactions-label">
#        <span class="vector-menu-heading-label">
#         More
#        </span>
#        <span class="vector-menu-checkbox-expanded">
#         expanded
#        </span>
#        <span class="vector-menu-checkbox-collapsed">
#         collapsed
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#        </ul>
#       </div>
#      </nav>
#      <div class="vector-search-box" id="p-search" role="search">
#       <div>
#        <h3>
#         <label for="searchInput">
#          Search
#         </label>
#        </h3>
#        <form action="/w/index.php" class="vector-search-box-form" id="searchform">
#         <div class="vector-search-box-inner" data-search-loc="header-navigation" id="simpleSearch">
#          <input accesskey="f" aria-label="Search Wikipedia" autocapitalize="sentences" class="vector-search-box-input" id="searchInput" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" type="search"/>
#          <input name="title" type="hidden" value="Special:Search"/>
#          <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search Wikipedia for this text" type="submit" value="Search"/>
#          <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="mw-panel">
#     <div id="p-logo" role="banner">
#      <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page">
#      </a>
#     </div>
#     <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal" id="p-navigation" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-navigation-label">
#       <span class="vector-menu-heading-label">
#        Navigation
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="n-mainpage-description">
#         <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]">
#          <span>
#           Main page
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-contents">
#         <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia">
#          <span>
#           Contents
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-currentevents">
#         <a href="/wiki/Portal:Current_events" title="Articles related to current events">
#          <span>
#           Current events
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-randompage">
#         <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]">
#          <span>
#           Random article
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-aboutsite">
#         <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works">
#          <span>
#           About Wikipedia
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          <span>
#           Contact us
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-sitesupport">
#         <a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us by donating to the Wikimedia Foundation">
#          <span>
#           Donate
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-interaction-label" class="mw-portlet mw-portlet-interaction vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-interaction-label">
#       <span class="vector-menu-heading-label">
#        Contribute
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="n-help">
#         <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">
#          <span>
#           Help
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-introduction">
#         <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">
#          <span>
#           Learn to edit
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-portal">
#         <a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">
#          <span>
#           Community portal
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-recentchanges">
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">
#          <span>
#           Recent changes
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="n-upload">
#         <a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">
#          <span>
#           Upload file
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-tb-label">
#       <span class="vector-menu-heading-label">
#        Tools
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/List_of_The_Open_Championship_champions" title="List of all English Wikipedia pages containing links to this page [j]">
#          <span>
#           What links here
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/List_of_The_Open_Championship_champions" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          <span>
#           Related changes
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          <span>
#           Upload file
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          <span>
#           Special pages
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-permalink">
#         <a href="/w/index.php?title=List_of_The_Open_Championship_champions&amp;oldid=1055436650" title="Permanent link to this revision of this page">
#          <span>
#           Permanent link
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-info">
#         <a href="/w/index.php?title=List_of_The_Open_Championship_champions&amp;action=info" title="More information about this page">
#          <span>
#           Page information
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_The_Open_Championship_champions&amp;id=1055436650&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">
#          <span>
#           Cite this page
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q6599896" title="Structured data on this page hosted by Wikidata [g]">
#          <span>
#           Wikidata item
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-coll-print_export-label">
#       <span class="vector-menu-heading-label">
#        Print/export
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#        <li class="mw-list-item" id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=List_of_The_Open_Championship_champions&amp;action=show-download-screen" title="Download this page as a PDF file">
#          <span>
#           Download as PDF
#          </span>
#         </a>
#        </li>
#        <li class="mw-list-item" id="t-print">
#         <a accesskey="p" href="/w/index.php?title=List_of_The_Open_Championship_champions&amp;printable=yes" title="Printable version of this page [p]">
#          <span>
#           Printable version
#          </span>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#      <h3 aria-label="" class="vector-menu-heading" id="p-lang-label">
#       <span class="vector-menu-heading-label">
#        Languages
#       </span>
#      </h3>
#      <div class="vector-menu-content">
#       <ul class="vector-menu-content-list">
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="uls-after-portlet-link">
#        </span>
#        <span class="wb-langlinks-add wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q6599896#sitelinks-wikipedia" title="Add interlanguage links">
#          Add links
#         </a>
#        </span>
#       </div>
#      </div>
#     </nav>
#    </div>
#   </div>
#   <footer class="mw-footer" id="footer" role="contentinfo">
#    <ul id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 15 November 2021, at 21:38
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=List_of_The_Open_Championship_champions&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#   </footer>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"2.060","walltime":"2.262","ppvisitednodes":{"value":22988,"limit":1000000},"postexpandincludesize":{"value":251753,"limit":2097152},"templateargumentsize":{"value":44565,"limit":2097152},"expansiondepth":{"value":17,"limit":100},"expensivefunctioncount":{"value":1,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":36774,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00% 1490.114      1 -total"," 18.23%  271.578    176 Template:Sortname"," 17.19%  256.113    244 Template:Sort"," 11.09%  165.210      5 Template:Cite_web","  7.30%  108.849      4 Template:Navbox","  6.44%   95.918     23 Template:Flagcountry","  6.16%   91.754      1 Template:Reflist","  5.86%   87.318      1 Template:The_Open_champions","  5.62%   83.681      1 Template:Short_description","  5.18%   77.163     27 Template:Flagathlete"]},"scribunto":{"limitreport-timeusage":{"value":"0.628","limit":"10.000"},"limitreport-memusage":{"value":5220458,"limit":52428800}},"cachereport":{"origin":"mw1363","timestamp":"20220128211450","ttl":1814400,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"List of The Open Championship champions","url":"https:\/\/en.wikipedia.org\/wiki\/List_of_The_Open_Championship_champions","sameAs":"http:\/\/www.wikidata.org\/entity\/Q6599896","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q6599896","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2008-07-22T16:59:32Z","dateModified":"2021-11-15T21:38:08Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/3\/33\/HarryVardon.jpg","headline":"Wikimedia list article"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":155,"wgHostname":"mw1441"});});
#   </script>
#  </body>
# </html>

# %%
#start process to extract only the table data
wiki_table = soup.find('table',{'class':'sortable plainrowheaders wikitable'}) #find what the class is in html code 
wiki_table_rows = wiki_table.find_all('tr')

# %%
#loop through and add elements to data array
data = []
for row in wiki_table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])

df = pd.DataFrame(data, columns=['Country', 'Champion','Course', 'Location', 'Total Score','Par']) # Change names for output columns
df = df[~df['Country'].isnull()]

# %%
#drop unassigned failsafe
df.drop(df[df['Country']=="Not assigned"].index,axis=0, inplace=True)

# %%
#sort data
df = df.reset_index(drop=True)

# %%
#view table data
df.head(10)
# Out:
#     Country         Champion               Course             Location  \
# 0  Scotland  Willie Park Sr.  Prestwick Golf Club  Prestwick, Scotland
# 1  Scotland   Tom Morris Sr.  Prestwick Golf Club  Prestwick, Scotland
# 2  Scotland   Tom Morris Sr.  Prestwick Golf Club  Prestwick, Scotland
# 3  Scotland  Willie Park Sr.  Prestwick Golf Club  Prestwick, Scotland
# 4  Scotland   Tom Morris Sr.  Prestwick Golf Club  Prestwick, Scotland
# 5  Scotland    Andrew Strath  Prestwick Golf Club  Prestwick, Scotland
# 6  Scotland  Willie Park Sr.  Prestwick Golf Club  Prestwick, Scotland
# 7  Scotland   Tom Morris Sr.  Prestwick Golf Club  Prestwick, Scotland
# 8  Scotland   Tom Morris Jr.  Prestwick Golf Club  Prestwick, Scotland
# 9  Scotland   Tom Morris Jr.  Prestwick Golf Club  Prestwick, Scotland
#
#   Total Score  Par
# 0         174  n/a
# 1         163  n/a
# 2         163  n/a
# 3         168  n/a
# 4         167  n/a
# 5         162  n/a
# 6         169  n/a
# 7         170  n/a
# 8         154  n/a
# 9         157  n/a

# %%
#convert df to csv
final_df.to_csv('ISO_codes.csv', index=False)

# %%
# download csv
final_df.to_csv(r"C:\Users\xxxx\xxxx\Documents\ML_projects\ISO_codes2.csv") # replace with your filepath

# %%
df_count = df.Country.value_counts()
print(df_count)
# Out:
# United States       45
# Scotland            41
# England             22
# —                   13
# South Africa        10
# Australia            9
# Jersey               7
# Northern Ireland     3
# Spain                3
# Ireland              3
# France               1
# New Zealand          1
# Argentina            1
# Zimbabwe             1
# Sweden               1
# Italy                1
# Name: Country, dtype: int64

# %%
df_count.head(5)
# Out:
# United States    45
# Scotland         41
# England          22
# —                13
# South Africa     10
# Name: Country, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.pie(df_count, labels = df_count.index, autopct='%1.0f%%', radius =2, pctdistance=1.1, labeldistance=1.2)
plt.legend(bbox_to_anchor=(2, 1.7))
plt.title(label ='Open Championship Winners by Country', y=1.5, fontsize=20)
plt.show()
